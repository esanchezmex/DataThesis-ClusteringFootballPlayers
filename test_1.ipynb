# %%
import fastparquet as fp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet('tracking_with_events.parquet')

# %%
df.shape
# Out:
# (15449416, 50)

# %%
# show all columns in pd dataframe
pd.set_option('display.max_columns', None)

# %%
# how may unique values in team column in df
df['team'].nunique()
# Out:
# 25
