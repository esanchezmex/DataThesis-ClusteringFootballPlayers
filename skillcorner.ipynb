# %%
import pandas as pd
import numpy as np
import skillcorner as sc
from kloppy import skillcorner as kloppy_sc
import json
import mplsoccer

# %%
# display all columns
pd.set_option('display.max_columns', None)

# %%
df =pd.read_parquet('match_2006551.parquet')
df.head()
# Out:
#    frame_number  minute  second  period  team  player_id  player_role_id  \
# 0             0       0     0.0       1 -9999      -9999           -9999
# 1             0       0     0.0       1  2757     334202               3
# 2             0       0     0.0       1  2757     127615               9
# 3             0       0     0.0       1  2751     333625              20
# 4             0       0     0.0       1  2751      19526              12
#
#        x      y  is_detected  player_in_possession  team_in_possession  \
# 0   9.44   5.73        False                 False               False
# 1  17.54   2.05        False                 False                True
# 2   3.17 -11.10        False                 False                True
# 3 -13.19 -11.68        False                 False               False
# 4  -2.34  15.58        False                 False               False
#
#    interpolated               team_name team_color  player_number  \
# ...

# %%
# read json file
with open('tracking_2006551.json', 'r') as f:
    data = json.load(f)
data
# Out:
# [{'frame': 0,
#   'timestamp': None,
#   'period': None,
#   'ball_data': {'x': None, 'y': None, 'z': None, 'is_detected': None},
#   'possession': {'player_id': None, 'group': None},
#   'image_corners_projection': {'x_top_left': None,
#    'y_top_left': None,
#    'x_bottom_left': None,
#    'y_bottom_left': None,
#    'x_bottom_right': None,
#    'y_bottom_right': None,
#    'x_top_right': None,
#    'y_top_right': None},
#   'player_data': []},
#  {'frame': 1,
#   'timestamp': None,
#   'period': None,
#   'ball_data': {'x': None, 'y': None, 'z': None, 'is_detected': None},
#   'possession': {'player_id': None, 'group': None},
#   'image_corners_projection': {'x_top_left': None,
#    'y_top_left': None,
#    'x_bottom_left': None,
#    'y_bottom_left': None,
#    'x_bottom_right': None,
#    'y_bottom_right': None,
#    'x_top_right': None,
#    'y_top_right': None},
#   'player_data': []},
#  {'frame': 2,
#   'timestamp': None,
#   'period': None,
# ...
